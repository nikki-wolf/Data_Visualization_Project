# %%
#Pandas,numpy, raw data, and drop NA's in points, price, country, and variety

import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
df = "../data/rawdata/winemag-data-130K-v2.csv"
df_one = pd.read_csv(df,index_col=0)
df_2 = df_one.dropna(subset=['points', 'price', 'country', 'variety'])
df_2.shape
# Out:
# (120915, 13)

# %%
#This in not necessary to include in group code. I used this just to see which ones occured more frequently
df_value_variety = df_2["variety"].value_counts(5)

# %%
#This is my list I created to group wines in the 103K spreadsheet per 9 main wine types. List name is Wine_types

Wine_types={'Bold Red': ['Malbec', 'Syrah','Red Blend','Shiraz', 'Mourvedre', 'Merlot','Bordeaux-style Red Blend', 'Pinotage', 'Petite Sirah', 'Touriga Nacional', 'Cabernet Sauvignon', 'Portuguese Red', 'Meritage'],
          'Medium Red': ['Meriot', 'Sangiovese', 'Rhône-style Red Blend','Zinfandel','Cabernet Franc', 'Tempranillo', 'Nebbiolo', 'Barbera', 'Cotes du Rhone Blend'],
          'Light Red':['Pinot Noir', 'Grenache', 'Gamay', 'St. Laurent', 'Carignan', 'Counoise'],
          'Rich White': ['Chardonnay', 'Semillon','Viognier', 'Marsanne', 'Roussanne'],
          'Light White': ['Bordeaux-style White Blend','Sauvignon Blanc', 'White Blend' , 'Albarino', 'Pitot Blanc', 'Vermentino', 'Melon de Bourgogne', 'Gargenega', 'Trebbiano', 'Pinot Gris', 'Pinot Grigio'],
          'Sweet White': ['Moscato', 'Riesling', 'Chenin Blanc', 'Gewurztraminer', 'Late Harvest Whites', 'Alascian Pinot Gris'],
          'Rosé': ['Rosé','Provencal Rose', 'White Zinfandel', 'Loire Valley Rose', 'Pinot Noir Rose', 'Syrah Rose', 'Garnache Rosado', 'Bandol Rose', 'Tempranilio Rose', 'Saignee Method Rose'],
          'Sparkling': ['Champagne', 'Prosecco', 'Cremant', 'Cava', 'Metodo Classico', 'Sparkling Wine', 'Sparkling Rose', 'Sparkling Blend', 'Champagne Blend'],
          'Dessert': ['Port', 'Sherry', 'Maderia', 'Vin Santo', 'Muscat', 'PX', 'Pedro Ximenez']
          }
Wine_types.keys()
# Out:
# dict_keys(['Bold Red', 'Medium Red', 'Light Red', 'Rich White', 'Light White', 'Sweet White', 'Rosé', 'Sparkling', 'Dessert'])

# %%
#Number of Values in our dictonary

ctr = sum(map(len, Wine_types.values()))
print(ctr)
# Out:
# 76

# %%
#If function that groups wines in the excel spreadsheet into the 9 main groups. If a value in the spreadsheet is not in list place into "other"
# df need to generate clean dataframe df_2.head

for x in Wine_types.keys():
    for y in range(len(Wine_types[x])):
       print('type=',x,'subtype=',Wine_types[x][y])
       A=df_2[df_2.variety.str.contains(Wine_types[x][y],na=False)].index.tolist()
       df_2.loc[A,'subvariety']=x
idx = df_2['subvariety'].isnull( )
df_2.loc[idx,'subvariety']='Others'
df_2.head()
# Out:
# type= Bold Red subtype= Malbec
# type= Bold Red subtype= Syrah
# type= Bold Red subtype= Red Blend
# type= Bold Red subtype= Shiraz
# type= Bold Red subtype= Mourvedre
# type= Bold Red subtype= Merlot
# type= Bold Red subtype= Bordeaux-style Red Blend
# type= Bold Red subtype= Pinotage
# type= Bold Red subtype= Petite Sirah
# type= Bold Red subtype= Touriga Nacional
# type= Bold Red subtype= Cabernet Sauvignon
# type= Bold Red subtype= Portuguese Red
# type= Bold Red subtype= Meritage
# type= Medium Red subtype= Meriot
# type= Medium Red subtype= Sangiovese
# type= Medium Red subtype= Rhône-style Red Blend
# type= Medium Red subtype= Zinfandel
# type= Medium Red subtype= Cabernet Franc
# type= Medium Red subtype= Tempranillo
# type= Medium Red subtype= Nebbiolo
# type= Medium Red subtype= Barbera
# type= Medium Red subtype= Cotes du Rhone Blend
# type= Light Red subtype= Pinot Noir
# type= Light Red subtype= Grenache
# type= Light Red subtype= Gamay
# ...

# %%
#import all libraries 
from pandas import ExcelWriter
from pandas import ExcelFile
import sqlalchemy
import sqlite3 as sq

# %%
clean_wine_rating = df_2.drop( ['province','vt','designation','description', 'region_1', 'region_2', 'taster_name', 'taster_twitter_handle', 'title','winery'] , axis='columns')
clean_wine_rating
# Out:
#             country  points  price                   variety   subvariety
# 1          Portugal      87   15.0            Portuguese Red      Dessert
# 2                US      87   14.0                Pinot Gris  Light White
# 3                US      87   13.0                  Riesling  Sweet White
# 4                US      87   65.0                Pinot Noir    Light Red
# 5             Spain      87   15.0        Tempranillo-Merlot   Medium Red
# 6             Italy      87   16.0                  Frappato       Others
# 7            France      87   24.0            Gewürztraminer       Others
# 8           Germany      87   12.0            Gewürztraminer       Others
# 9            France      87   27.0                Pinot Gris  Light White
# 10               US      87   19.0        Cabernet Sauvignon     Bold Red
# 11           France      87   30.0            Gewürztraminer       Others
# 12               US      87   34.0        Cabernet Sauvignon     Bold Red
# ...

# %%
clean_wine_rating.shape
# Out:
# (120915, 5)

# %%
clean_wine_rating.iloc[1,2]
# Out:
# 14.0

# %%
#for i  in range(10):
    #cell={'country': clean_wine_rating.iloc[i,0],
           #'rating':clean_wine_rating.iloc[i,1],
           #'price': clean_wine_rating.iloc[i,2],
           #'variety': clean_wine_rating.iloc[i,4],
           #'subvariety': clean_wine_rating.iloc[i,3],
    
    #clean_wine_rating.insert_one(cell)

# %%
import pymongo
# The default port used by MongoDB is 27017

conn_local='mongodb://localhost:27017'

mlab_ID={
    "_id": "heroku_stp5z9b7.pygeons",
    "user": "pygeons",
    "db": "heroku_stp5z9b7",
    "roles": [
        {
            "role": "dbOwner",
            "db": "heroku_stp5z9b7"
        }
    ],
    "pass":'pygeons2019'
}

# %%
conn_mlab='mongodb://{one}:{two}@ds231377.mlab.com:31377/{three}'\
            .format(one=mlab_ID['user'], two=mlab_ID['pass'], three=mlab_ID['db'])
client = pymongo.MongoClient(conn_mlab)

# Define the 'wine' database in mlab
db = client.heroku_stp5z9b7
wine_rating_mongo=db.wine_rating

# %%
#works!!
#for i  in range(clean_wine_rating.shape[0]):
    #cell={'country': clean_wine_rating.iloc[i,0],
           #'rating':str(clean_wine_rating.iloc[i,1]),
           #'price': str(clean_wine_rating.iloc[i,2]),
           #'variety': clean_wine_rating.iloc[i,4],
           #'subvariety': clean_wine_rating.iloc[i,3]}
    #wine_rating_mongo.insert_one(cell)

# %%
n=8061
for i  in range(int(clean_wine_rating.shape[0]/n)):
#for i  in range(1):
    row=[]
    for j in range(n):
        cell={'country': clean_wine_rating.iloc[i*n+j,0],
               'rating':str(clean_wine_rating.iloc[i*n+j,1]),
               'price': str(clean_wine_rating.iloc[i*n+j,2]),
               'variety': clean_wine_rating.iloc[i*n+j,4],
               'subvariety': clean_wine_rating.iloc[i*n+j,3]}
        row.append(cell)
    
    #print(row)
    wine_rating_mongo.insert_many(row)

# %%
clean_wine_rating.shape[0]
# Out:
# 120915

# %%
120915/15
# Out:
# 8061.0

# %%
clean_wine_rating.shape[0]/n
# Out:
# 15.0
